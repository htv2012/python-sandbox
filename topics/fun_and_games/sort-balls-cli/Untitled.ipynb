# %%
from scb.data import grid

# %%
grid
# Out:
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
# |---|---|---|---|---|---|---|---|
# | b | d | c | f | b | g | e |   |
# | a | g | a | e | g | b | a |   |
# | c | c | a | d | c | c | f |   |
# | e | c | d | e | g | a | f |   |
# | c | g | a | d | f | d | f |   |
# | f | e | e | g | d | f | b |   |
# | b | g | e | a | g | e | d |   |
# | c | b | f | b | b | a | d |   |

# %%
grid.move(4, 7)
grid
# Out:
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
# |---|---|---|---|---|---|---|---|
# | b | d | c | f |   | g | e |   |
# | a | g | a | e | g | b | a |   |
# | c | c | a | d | c | c | f |   |
# | e | c | d | e | g | a | f |   |
# | c | g | a | d | f | d | f |   |
# | f | e | e | g | d | f | b |   |
# | b | g | e | a | g | e | d |   |
# | c | b | f | b | b | a | d | b |

# %%
grid.move(0, 7)
grid
# Out:
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
# |---|---|---|---|---|---|---|---|
# |   | d | c | f |   | g | e |   |
# | a | g | a | e | g | b | a |   |
# | c | c | a | d | c | c | f |   |
# | e | c | d | e | g | a | f |   |
# | c | g | a | d | f | d | f |   |
# | f | e | e | g | d | f | b |   |
# | b | g | e | a | g | e | d | b |
# | c | b | f | b | b | a | d | b |

# %%
x, y = [int(i) for i in "12"]
x, y
# Out:
# (1, 2)
