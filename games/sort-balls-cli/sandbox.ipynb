# %%
from scb.grid import Grid

# %%
g = Grid()

# %%
g.put(0, "a")
g
# Out:
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
# |---|---|---|---|---|---|---|---|
# |   |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |   |
# | a |   |   |   |   |   |   |   |

# %%
g[0]
# Out:
# Stack['a']

# %%
g[7]
# Out:
# Stack['b', 'b', 'b']

# %%
g.put(7, "b")

# %%
g
# Out:
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
# |---|---|---|---|---|---|---|---|
# |   |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   | b |
# |   |   |   |   |   |   |   | b |
# | a |   |   |   |   |   |   | b |
